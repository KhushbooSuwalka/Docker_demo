# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers = ["kafka:9092"],
    value_serializer = lambda v: json.dumps(v).encode('utf-8')
)

user_ids = [101,102,103,104,105]

print("starting transaction producer...")

for i in range(100):
    tx_data = {
        "tx_id":i,
        "userId": random.choice(user_ids),
        "amount": random.uniform(10.0,15000.0), # >10000 fraud
        "timestamp":time.time()
    }
    producer.send('fraud-detection',value=tx_data)
    print(f"Sent: {tx_data}")
    time.sleep(2)
# Out:
# starting transaction producer...
# Sent: {'tx_id': 0, 'userId': 104, 'amount': 717.1792039084969, 'timestamp': 1781782097.6349478}
# Sent: {'tx_id': 1, 'userId': 102, 'amount': 12442.494880357262, 'timestamp': 1781782099.7356768}
# Sent: {'tx_id': 2, 'userId': 103, 'amount': 14282.778124737095, 'timestamp': 1781782101.7374604}
# Sent: {'tx_id': 3, 'userId': 101, 'amount': 10107.621906353783, 'timestamp': 1781782103.7383013}
# Sent: {'tx_id': 4, 'userId': 102, 'amount': 8470.675484319932, 'timestamp': 1781782105.7396185}
# Sent: {'tx_id': 5, 'userId': 105, 'amount': 10838.914656512845, 'timestamp': 1781782107.7409708}
# Sent: {'tx_id': 6, 'userId': 105, 'amount': 3194.684453674289, 'timestamp': 1781782109.7416644}
# Sent: {'tx_id': 7, 'userId': 101, 'amount': 10781.937969347775, 'timestamp': 1781782111.7425303}
# Sent: {'tx_id': 8, 'userId': 102, 'amount': 10660.350384662259, 'timestamp': 1781782113.7432668}
# Sent: {'tx_id': 9, 'userId': 102, 'amount': 7132.695425042031, 'timestamp': 1781782115.746637}
# Sent: {'tx_id': 10, 'userId': 101, 'amount': 10006.841920334638, 'timestamp': 1781782117.7486503}
# Sent: {'tx_id': 11, 'userId': 105, 'amount': 4150.309111453492, 'timestamp': 1781782119.745527}
# Sent: {'tx_id': 12, 'userId': 105, 'amount': 11512.767738344728, 'timestamp': 1781782121.7463074}
# Sent: {'tx_id': 13, 'userId': 103, 'amount': 12995.31721835188, 'timestamp': 1781782123.747111}
# Sent: {'tx_id': 14, 'userId': 102, 'amount': 1070.7240141498648, 'timestamp': 1781782125.7480526}
# Sent: {'tx_id': 15, 'userId': 104, 'amount': 10726.305939979255, 'timestamp': 1781782127.7488189}
# Sent: {'tx_id': 16, 'userId': 101, 'amount': 8392.540164313614, 'timestamp': 1781782129.749491}
# Sent: {'tx_id': 17, 'userId': 103, 'amount': 6682.899826008752, 'timestamp': 1781782131.7503266}
# Sent: {'tx_id': 18, 'userId': 105, 'amount': 1035.4477905942613, 'timestamp': 1781782133.7511668}
# Sent: {'tx_id': 19, 'userId': 102, 'amount': 4203.567341457383, 'timestamp': 1781782135.7520278}
# Sent: {'tx_id': 20, 'userId': 102, 'amount': 7187.176212913561, 'timestamp': 1781782137.753538}
# Sent: {'tx_id': 21, 'userId': 103, 'amount': 9742.440966106928, 'timestamp': 1781782139.7547967}
# Sent: {'tx_id': 22, 'userId': 104, 'amount': 2277.0744496524358, 'timestamp': 1781782141.7555678}
# Sent: {'tx_id': 23, 'userId': 105, 'amount': 1416.6534916572764, 'timestamp': 1781782143.7567353}
# Sent: {'tx_id': 24, 'userId': 101, 'amount': 4398.757036870658, 'timestamp': 1781782145.758575}
# Sent: {'tx_id': 25, 'userId': 104, 'amount': 4350.387830760974, 'timestamp': 1781782147.7595968}
# Sent: {'tx_id': 26, 'userId': 102, 'amount': 638.7669255880468, 'timestamp': 1781782149.7613788}
# Sent: {'tx_id': 27, 'userId': 104, 'amount': 5287.650217112873, 'timestamp': 1781782151.763094}
# Sent: {'tx_id': 28, 'userId': 104, 'amount': 7504.524267302664, 'timestamp': 1781782153.7666237}
# Sent: {'tx_id': 29, 'userId': 105, 'amount': 6039.29719109416, 'timestamp': 1781782155.76929}
# Sent: {'tx_id': 30, 'userId': 103, 'amount': 5392.113281861411, 'timestamp': 1781782157.7703943}
# Sent: {'tx_id': 31, 'userId': 101, 'amount': 7103.448527996459, 'timestamp': 1781782159.7718594}
# Sent: {'tx_id': 32, 'userId': 104, 'amount': 8034.288564213329, 'timestamp': 1781782161.7731297}
# Sent: {'tx_id': 33, 'userId': 104, 'amount': 10562.36518844483, 'timestamp': 1781782163.7760227}
# Sent: {'tx_id': 34, 'userId': 105, 'amount': 10812.02207498637, 'timestamp': 1781782165.7791173}
# Sent: {'tx_id': 35, 'userId': 102, 'amount': 9941.42142901746, 'timestamp': 1781782167.781586}
# Sent: {'tx_id': 36, 'userId': 105, 'amount': 8819.109742962863, 'timestamp': 1781782169.78352}
# Sent: {'tx_id': 37, 'userId': 102, 'amount': 13553.990466792546, 'timestamp': 1781782171.7859259}
# Sent: {'tx_id': 38, 'userId': 101, 'amount': 13587.586179029699, 'timestamp': 1781782173.787438}
# Sent: {'tx_id': 39, 'userId': 102, 'amount': 12809.902723555735, 'timestamp': 1781782175.7886708}
# Sent: {'tx_id': 40, 'userId': 102, 'amount': 8713.67951500844, 'timestamp': 1781782177.7893124}
# Sent: {'tx_id': 41, 'userId': 102, 'amount': 11763.675892380412, 'timestamp': 1781782179.7859395}
# Sent: {'tx_id': 42, 'userId': 103, 'amount': 840.3794507569693, 'timestamp': 1781782181.7874482}
# Sent: {'tx_id': 43, 'userId': 101, 'amount': 10555.679564145516, 'timestamp': 1781782183.7882826}
# Sent: {'tx_id': 44, 'userId': 102, 'amount': 9315.917153793687, 'timestamp': 1781782185.7896225}
# Sent: {'tx_id': 45, 'userId': 105, 'amount': 6932.982699946496, 'timestamp': 1781782187.7921543}
# Sent: {'tx_id': 46, 'userId': 104, 'amount': 8971.49097874726, 'timestamp': 1781782189.7932043}
# Sent: {'tx_id': 47, 'userId': 104, 'amount': 12305.524674230412, 'timestamp': 1781782191.7944975}
# Sent: {'tx_id': 48, 'userId': 104, 'amount': 2622.2137152681903, 'timestamp': 1781782193.7956905}
# Sent: {'tx_id': 49, 'userId': 105, 'amount': 2627.3097874794266, 'timestamp': 1781782195.7965982}
# Sent: {'tx_id': 50, 'userId': 102, 'amount': 6110.621928568111, 'timestamp': 1781782197.798199}
# Sent: {'tx_id': 51, 'userId': 102, 'amount': 12490.723280617334, 'timestamp': 1781782199.7997086}
# Sent: {'tx_id': 52, 'userId': 103, 'amount': 13258.868905382102, 'timestamp': 1781782201.8008816}
# Sent: {'tx_id': 53, 'userId': 101, 'amount': 12951.009964330186, 'timestamp': 1781782203.802131}
# Sent: {'tx_id': 54, 'userId': 104, 'amount': 8307.913333658153, 'timestamp': 1781782205.803558}
# Sent: {'tx_id': 55, 'userId': 102, 'amount': 5309.018958820057, 'timestamp': 1781782207.8071153}
# Sent: {'tx_id': 56, 'userId': 104, 'amount': 12498.33640551908, 'timestamp': 1781782209.8085015}
# Sent: {'tx_id': 57, 'userId': 103, 'amount': 13815.84075141905, 'timestamp': 1781782211.8111644}
# Sent: {'tx_id': 58, 'userId': 102, 'amount': 7335.4716682537055, 'timestamp': 1781782213.8125117}
# Sent: {'tx_id': 59, 'userId': 101, 'amount': 8650.867993621932, 'timestamp': 1781782215.8140156}
# Sent: {'tx_id': 60, 'userId': 101, 'amount': 10495.783432099728, 'timestamp': 1781782217.8180711}
# Sent: {'tx_id': 61, 'userId': 104, 'amount': 13624.68653889114, 'timestamp': 1781782219.8194406}
# Sent: {'tx_id': 62, 'userId': 101, 'amount': 251.8849146245519, 'timestamp': 1781782221.822789}
# Sent: {'tx_id': 63, 'userId': 102, 'amount': 12478.586435393741, 'timestamp': 1781782223.8238106}
# Sent: {'tx_id': 64, 'userId': 105, 'amount': 11460.806780339874, 'timestamp': 1781782225.8255668}
# Sent: {'tx_id': 65, 'userId': 101, 'amount': 9451.377916873733, 'timestamp': 1781782227.8271587}
# Sent: {'tx_id': 66, 'userId': 103, 'amount': 6245.163937608969, 'timestamp': 1781782229.8281858}
# Sent: {'tx_id': 67, 'userId': 104, 'amount': 7526.34415112058, 'timestamp': 1781782231.8294578}
# Sent: {'tx_id': 68, 'userId': 102, 'amount': 431.7919593437269, 'timestamp': 1781782233.830631}
# Sent: {'tx_id': 69, 'userId': 102, 'amount': 253.93190406347767, 'timestamp': 1781782235.8335648}
# Sent: {'tx_id': 70, 'userId': 105, 'amount': 14374.547719443313, 'timestamp': 1781782237.8345134}
# Sent: {'tx_id': 71, 'userId': 105, 'amount': 14325.870249944921, 'timestamp': 1781782239.8334522}
# Sent: {'tx_id': 72, 'userId': 105, 'amount': 3621.3047934188908, 'timestamp': 1781782241.8353047}
# Sent: {'tx_id': 73, 'userId': 101, 'amount': 2444.0252211942598, 'timestamp': 1781782243.83682}
# Sent: {'tx_id': 74, 'userId': 102, 'amount': 10968.243981976084, 'timestamp': 1781782245.8381703}
# Sent: {'tx_id': 75, 'userId': 101, 'amount': 8540.644299851736, 'timestamp': 1781782247.8397884}
# Sent: {'tx_id': 76, 'userId': 102, 'amount': 13474.968964539652, 'timestamp': 1781782249.8404443}
# Sent: {'tx_id': 77, 'userId': 105, 'amount': 13079.126969069028, 'timestamp': 1781782251.8416023}
# Sent: {'tx_id': 78, 'userId': 104, 'amount': 5130.343504589285, 'timestamp': 1781782253.8427837}
# Sent: {'tx_id': 79, 'userId': 105, 'amount': 5550.2154985986945, 'timestamp': 1781782255.8439445}
# Sent: {'tx_id': 80, 'userId': 103, 'amount': 5089.481226267688, 'timestamp': 1781782257.845136}
# Sent: {'tx_id': 81, 'userId': 102, 'amount': 14268.057646931404, 'timestamp': 1781782259.8480885}
# Sent: {'tx_id': 82, 'userId': 103, 'amount': 1313.1699506149823, 'timestamp': 1781782261.849151}
# Sent: {'tx_id': 83, 'userId': 103, 'amount': 2370.8487725341865, 'timestamp': 1781782263.8501165}
# Sent: {'tx_id': 84, 'userId': 101, 'amount': 12952.953855400163, 'timestamp': 1781782265.851425}
# Sent: {'tx_id': 85, 'userId': 101, 'amount': 199.66822908201917, 'timestamp': 1781782267.8541203}
# Sent: {'tx_id': 86, 'userId': 103, 'amount': 8675.210046747206, 'timestamp': 1781782269.852224}
# Sent: {'tx_id': 87, 'userId': 104, 'amount': 5436.39434910104, 'timestamp': 1781782271.8533022}
# Sent: {'tx_id': 88, 'userId': 104, 'amount': 11550.33996645654, 'timestamp': 1781782273.854158}
# Sent: {'tx_id': 89, 'userId': 103, 'amount': 12019.381127188644, 'timestamp': 1781782275.8552463}
# Sent: {'tx_id': 90, 'userId': 101, 'amount': 14200.055661615866, 'timestamp': 1781782277.8563466}
# Sent: {'tx_id': 91, 'userId': 103, 'amount': 9613.775803262512, 'timestamp': 1781782279.8606582}
# Sent: {'tx_id': 92, 'userId': 102, 'amount': 5769.959761482746, 'timestamp': 1781782281.86582}
# Sent: {'tx_id': 93, 'userId': 105, 'amount': 11588.908414714144, 'timestamp': 1781782283.8702152}
# Sent: {'tx_id': 94, 'userId': 101, 'amount': 11158.40900640977, 'timestamp': 1781782285.8711884}
# Sent: {'tx_id': 95, 'userId': 105, 'amount': 11753.638093746755, 'timestamp': 1781782287.8728516}
# Sent: {'tx_id': 96, 'userId': 101, 'amount': 7302.202752139888, 'timestamp': 1781782289.8742967}
# Sent: {'tx_id': 97, 'userId': 103, 'amount': 14322.609074530963, 'timestamp': 1781782291.875158}
# Sent: {'tx_id': 98, 'userId': 102, 'amount': 2072.112049195676, 'timestamp': 1781782293.8760855}
# Sent: {'tx_id': 99, 'userId': 104, 'amount': 3966.1726306358746, 'timestamp': 1781782295.8771338}
