# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers = ["kafka:9092"],
    value_serializer = lambda v: json.dumps(v).encode('utf-8')
)

user_ids = [101,102,103,104,105]

print("starting transaction producer...")

for i in range(100):
    tx_data = {
        "tx_id":i,
        "userId": random.choice(user_ids),
        "amount": random.uniform(10.0,15000.0), # >10000 fraud
        "timestamp":time.time()
    }
    producer.send('fraud-detection',value=tx_data)
    print(f"Sent: {tx_data}")
    time.sleep(2)
# Out:
# starting transaction producer...
# Sent: {'tx_id': 0, 'userId': 102, 'amount': 12331.995015439279, 'timestamp': 1781871409.178029}
# Sent: {'tx_id': 1, 'userId': 103, 'amount': 10322.86178253732, 'timestamp': 1781871411.2744596}
# Sent: {'tx_id': 2, 'userId': 104, 'amount': 9856.200820716473, 'timestamp': 1781871413.2760994}
# Sent: {'tx_id': 3, 'userId': 105, 'amount': 10827.952362163149, 'timestamp': 1781871415.2769556}
# Sent: {'tx_id': 4, 'userId': 104, 'amount': 6025.243368880186, 'timestamp': 1781871417.2781203}
# Sent: {'tx_id': 5, 'userId': 104, 'amount': 12699.774051845712, 'timestamp': 1781871419.2833822}
# Sent: {'tx_id': 6, 'userId': 102, 'amount': 1644.0481174915801, 'timestamp': 1781871421.2844155}
# Sent: {'tx_id': 7, 'userId': 104, 'amount': 12849.22854031853, 'timestamp': 1781871423.2890677}
# Sent: {'tx_id': 8, 'userId': 105, 'amount': 11923.901042514704, 'timestamp': 1781871425.2901375}
# Sent: {'tx_id': 9, 'userId': 104, 'amount': 8021.197868323863, 'timestamp': 1781871427.2935169}
# Sent: {'tx_id': 10, 'userId': 104, 'amount': 2972.0085964968493, 'timestamp': 1781871429.2941048}
# Sent: {'tx_id': 11, 'userId': 103, 'amount': 3655.5819956317205, 'timestamp': 1781871431.2947223}
# Sent: {'tx_id': 12, 'userId': 105, 'amount': 14605.71366573194, 'timestamp': 1781871433.2962072}
# Sent: {'tx_id': 13, 'userId': 102, 'amount': 4449.351776072383, 'timestamp': 1781871435.2976413}
# Sent: {'tx_id': 14, 'userId': 105, 'amount': 8790.49489891404, 'timestamp': 1781871437.298723}
# Sent: {'tx_id': 15, 'userId': 105, 'amount': 8866.57167791209, 'timestamp': 1781871439.2999303}
# Sent: {'tx_id': 16, 'userId': 104, 'amount': 2863.473777704428, 'timestamp': 1781871441.3009264}
# Sent: {'tx_id': 17, 'userId': 105, 'amount': 12300.582606219723, 'timestamp': 1781871443.3017209}
# Sent: {'tx_id': 18, 'userId': 101, 'amount': 12680.114534839044, 'timestamp': 1781871445.303687}
# Sent: {'tx_id': 19, 'userId': 104, 'amount': 3609.3757604927123, 'timestamp': 1781871447.3052204}
# Sent: {'tx_id': 20, 'userId': 103, 'amount': 1246.8169584307268, 'timestamp': 1781871449.3071685}
# Sent: {'tx_id': 21, 'userId': 105, 'amount': 14812.6468672652, 'timestamp': 1781871451.3119934}
# Sent: {'tx_id': 22, 'userId': 102, 'amount': 5975.905179254266, 'timestamp': 1781871453.3133156}
# Sent: {'tx_id': 23, 'userId': 102, 'amount': 284.24414032812433, 'timestamp': 1781871455.3141637}
# Sent: {'tx_id': 24, 'userId': 103, 'amount': 10970.778310041096, 'timestamp': 1781871457.315843}
# Sent: {'tx_id': 25, 'userId': 101, 'amount': 13315.684868673434, 'timestamp': 1781871459.3172853}
# Sent: {'tx_id': 26, 'userId': 105, 'amount': 10943.38962649016, 'timestamp': 1781871461.3148336}
# Sent: {'tx_id': 27, 'userId': 105, 'amount': 927.5086101718688, 'timestamp': 1781871463.31606}
# Sent: {'tx_id': 28, 'userId': 105, 'amount': 10934.683286944066, 'timestamp': 1781871465.3194404}
# Sent: {'tx_id': 29, 'userId': 101, 'amount': 3326.3898163908652, 'timestamp': 1781871467.3207996}
# Sent: {'tx_id': 30, 'userId': 104, 'amount': 332.8882005975108, 'timestamp': 1781871469.3230278}
# Sent: {'tx_id': 31, 'userId': 104, 'amount': 4889.121862130392, 'timestamp': 1781871471.3268123}
# Sent: {'tx_id': 32, 'userId': 101, 'amount': 4761.798802209931, 'timestamp': 1781871473.329477}
# Sent: {'tx_id': 33, 'userId': 105, 'amount': 8205.190583506786, 'timestamp': 1781871475.3307703}
# Sent: {'tx_id': 34, 'userId': 105, 'amount': 5010.740271684685, 'timestamp': 1781871477.3345618}
# Sent: {'tx_id': 35, 'userId': 104, 'amount': 2471.2230975925754, 'timestamp': 1781871479.335983}
# Sent: {'tx_id': 36, 'userId': 105, 'amount': 8509.656685123498, 'timestamp': 1781871481.3372192}
# Sent: {'tx_id': 37, 'userId': 104, 'amount': 12301.442825113681, 'timestamp': 1781871483.337908}
# Sent: {'tx_id': 38, 'userId': 101, 'amount': 7114.3967090768165, 'timestamp': 1781871485.338778}
# Sent: {'tx_id': 39, 'userId': 104, 'amount': 4607.195145468803, 'timestamp': 1781871487.3411891}
# Sent: {'tx_id': 40, 'userId': 103, 'amount': 711.3905582848738, 'timestamp': 1781871489.342513}
# Sent: {'tx_id': 41, 'userId': 105, 'amount': 9642.921534437959, 'timestamp': 1781871491.3406203}
# Sent: {'tx_id': 42, 'userId': 103, 'amount': 2712.234798813122, 'timestamp': 1781871493.3441978}
# Sent: {'tx_id': 43, 'userId': 105, 'amount': 4196.348119873684, 'timestamp': 1781871495.3475018}
# Sent: {'tx_id': 44, 'userId': 104, 'amount': 1421.1375507645946, 'timestamp': 1781871497.34856}
# Sent: {'tx_id': 45, 'userId': 102, 'amount': 12859.757248225425, 'timestamp': 1781871499.3495443}
# Sent: {'tx_id': 46, 'userId': 102, 'amount': 925.3542360195663, 'timestamp': 1781871501.3524728}
# Sent: {'tx_id': 47, 'userId': 105, 'amount': 10049.850449978134, 'timestamp': 1781871503.3547785}
# Sent: {'tx_id': 48, 'userId': 102, 'amount': 1815.4113044078406, 'timestamp': 1781871505.355794}
# Sent: {'tx_id': 49, 'userId': 101, 'amount': 7459.399968031987, 'timestamp': 1781871507.3570018}
# Sent: {'tx_id': 50, 'userId': 105, 'amount': 3116.949592143353, 'timestamp': 1781871509.3582215}
# Sent: {'tx_id': 51, 'userId': 102, 'amount': 7820.0005356851725, 'timestamp': 1781871511.3592696}
# Sent: {'tx_id': 52, 'userId': 104, 'amount': 12231.977614137299, 'timestamp': 1781871513.3604171}
# Sent: {'tx_id': 53, 'userId': 102, 'amount': 3622.505371188436, 'timestamp': 1781871515.3624487}
# Sent: {'tx_id': 54, 'userId': 102, 'amount': 9592.30748772516, 'timestamp': 1781871517.3639984}
# Sent: {'tx_id': 55, 'userId': 104, 'amount': 3429.764666633382, 'timestamp': 1781871519.3653066}
# Sent: {'tx_id': 56, 'userId': 102, 'amount': 6931.429703659288, 'timestamp': 1781871521.3621385}
# Sent: {'tx_id': 57, 'userId': 105, 'amount': 9219.749476967276, 'timestamp': 1781871523.363509}
# Sent: {'tx_id': 58, 'userId': 105, 'amount': 9939.342413813083, 'timestamp': 1781871525.3647542}
# Sent: {'tx_id': 59, 'userId': 101, 'amount': 2878.156417133045, 'timestamp': 1781871527.3661618}
# Sent: {'tx_id': 60, 'userId': 105, 'amount': 5656.609102123252, 'timestamp': 1781871529.367373}
# Sent: {'tx_id': 61, 'userId': 101, 'amount': 13588.727876960153, 'timestamp': 1781871531.368941}
# Sent: {'tx_id': 62, 'userId': 101, 'amount': 1642.3831552925294, 'timestamp': 1781871533.369953}
# Sent: {'tx_id': 63, 'userId': 101, 'amount': 2915.205624920154, 'timestamp': 1781871535.3720977}
# Sent: {'tx_id': 64, 'userId': 104, 'amount': 570.2330191383248, 'timestamp': 1781871537.373546}
# Sent: {'tx_id': 65, 'userId': 105, 'amount': 1183.0560801263873, 'timestamp': 1781871539.374604}
# Sent: {'tx_id': 66, 'userId': 103, 'amount': 1293.4153417539858, 'timestamp': 1781871541.3781748}
# Sent: {'tx_id': 67, 'userId': 104, 'amount': 2831.8727897706963, 'timestamp': 1781871543.3827386}
# Sent: {'tx_id': 68, 'userId': 104, 'amount': 12781.513064446757, 'timestamp': 1781871545.3841512}
# Sent: {'tx_id': 69, 'userId': 104, 'amount': 13034.793854229409, 'timestamp': 1781871547.3855042}
# Sent: {'tx_id': 70, 'userId': 105, 'amount': 14561.060328886977, 'timestamp': 1781871549.386684}
# Sent: {'tx_id': 71, 'userId': 102, 'amount': 2855.071968655936, 'timestamp': 1781871551.3863828}
# Sent: {'tx_id': 72, 'userId': 105, 'amount': 8169.444444261755, 'timestamp': 1781871553.3911245}
# Sent: {'tx_id': 73, 'userId': 105, 'amount': 8373.964555456057, 'timestamp': 1781871555.3922522}
# Sent: {'tx_id': 74, 'userId': 101, 'amount': 9411.715611554539, 'timestamp': 1781871557.3951235}
# Sent: {'tx_id': 75, 'userId': 103, 'amount': 11166.138062077116, 'timestamp': 1781871559.396227}
# Sent: {'tx_id': 76, 'userId': 102, 'amount': 4597.49714553279, 'timestamp': 1781871561.3978007}
# Sent: {'tx_id': 77, 'userId': 102, 'amount': 12576.537172460661, 'timestamp': 1781871563.4003546}
# Sent: {'tx_id': 78, 'userId': 101, 'amount': 5565.197986484848, 'timestamp': 1781871565.40309}
# Sent: {'tx_id': 79, 'userId': 105, 'amount': 3181.8972023190568, 'timestamp': 1781871567.4042196}
# Sent: {'tx_id': 80, 'userId': 103, 'amount': 2497.1612661215822, 'timestamp': 1781871569.4054756}
# Sent: {'tx_id': 81, 'userId': 101, 'amount': 6749.964790525762, 'timestamp': 1781871571.4062178}
# Sent: {'tx_id': 82, 'userId': 105, 'amount': 9540.98258791173, 'timestamp': 1781871573.4089017}
# Sent: {'tx_id': 83, 'userId': 101, 'amount': 2464.2739411615134, 'timestamp': 1781871575.4100685}
# Sent: {'tx_id': 84, 'userId': 103, 'amount': 2652.893123434805, 'timestamp': 1781871577.4122083}
# Sent: {'tx_id': 85, 'userId': 101, 'amount': 7281.915340803713, 'timestamp': 1781871579.4135087}
# Sent: {'tx_id': 86, 'userId': 105, 'amount': 9402.04530840017, 'timestamp': 1781871581.4098136}
# Sent: {'tx_id': 87, 'userId': 104, 'amount': 3194.0512898640677, 'timestamp': 1781871583.4115834}
# Sent: {'tx_id': 88, 'userId': 102, 'amount': 6818.234027346934, 'timestamp': 1781871585.4165633}
# Sent: {'tx_id': 89, 'userId': 105, 'amount': 5752.616557652147, 'timestamp': 1781871587.417429}
# Sent: {'tx_id': 90, 'userId': 101, 'amount': 7520.703096276226, 'timestamp': 1781871589.4196465}
# Sent: {'tx_id': 91, 'userId': 102, 'amount': 4328.088161508676, 'timestamp': 1781871591.4207628}
# Sent: {'tx_id': 92, 'userId': 103, 'amount': 1093.0436121135162, 'timestamp': 1781871593.421851}
# Sent: {'tx_id': 93, 'userId': 102, 'amount': 11748.875507326282, 'timestamp': 1781871595.4245257}
# Sent: {'tx_id': 94, 'userId': 103, 'amount': 873.0407847640878, 'timestamp': 1781871597.4256918}
# Sent: {'tx_id': 95, 'userId': 104, 'amount': 14305.201492192275, 'timestamp': 1781871599.4271102}
# Sent: {'tx_id': 96, 'userId': 102, 'amount': 1230.7031544274264, 'timestamp': 1781871601.4281225}
# Sent: {'tx_id': 97, 'userId': 105, 'amount': 12556.496479838293, 'timestamp': 1781871603.4292943}
# Sent: {'tx_id': 98, 'userId': 102, 'amount': 14232.392845671602, 'timestamp': 1781871605.43032}
# Sent: {'tx_id': 99, 'userId': 102, 'amount': 10714.569633018022, 'timestamp': 1781871607.4314892}
