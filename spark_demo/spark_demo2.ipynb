# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Employee") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/12 17:13:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/12 17:13:52 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
data = [
    (1, "Alice", "Engineering", 75000, 25),
    (2, "Bob", "Marketing", 60000, 30),
    (3, "Charlie", "Engineering", 80000, 35),
    (4, "David", "Sales", 65000, 28),
    (5, "Eve", "Marketing", 70000, 32)
]
columns = ["Id", "Name", "Department", "Salary", "Age"]
df = spark.createDataFrame(data, columns);

# %%
df.write.mode("overwrite").csv("output/employeetable", header=True)

# %%
df.toPandas().to_csv(
    "output/employee123.csv",
    index=False
)

# %%
df = spark.read \
.option("header",True) \
.csv("output/employeetable")

# %%
df.createOrReplaceTempView("employees")

# %%
result=spark.sql("""
SELECT * FROM employees where Salary > 70000
""").show()
# Out:
# +---+-------+-----------+------+---+
# | Id|   Name| Department|Salary|Age|
# +---+-------+-----------+------+---+
# |  3|Charlie|Engineering| 80000| 35|
# |  1|  Alice|Engineering| 75000| 25|
# +---+-------+-----------+------+---+
